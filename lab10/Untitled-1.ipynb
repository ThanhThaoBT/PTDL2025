# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

path = "facebook_combined.txt"
G = nx.read_edgelist(path, create_using=nx.Graph(), nodetype=int)

print("Số nút:", G.number_of_nodes())
print("Số cạnh:", G.number_of_edges())
print("Mật độ:", nx.density(G))
print("Clustering trung bình:", nx.average_clustering(G))
# Out:
# Số nút: 4039
# Số cạnh: 88234
# Mật độ: 0.010819963503439287
# Clustering trung bình: 0.6055467186200862
